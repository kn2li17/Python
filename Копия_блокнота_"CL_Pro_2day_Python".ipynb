# %% [markdown]
# <a href="https://colab.research.google.com/github/kn2li17/Python/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22CL_Pro_2day_Python%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **СДЕЛАЙТЕ КОПИЮ ЭТОГО ФАЙЛА СЕБЕ НА DRIVE**
#
# Вы не сможете работать в этом файле

# %% [markdown]
# # Данные
# #### [Our World in Data website](https://ourworldindata.org/coronavirus-source-data)
# #### [Our World in Data GitHub](https://github.com/owid/covid-19-data/tree/master/public/data/)

# %% [markdown]
# Вопрос европейского заказчика:
#
# ***На какой рынок сейчас стоит выходить, если рассматривать ситуацию с COVID-19?***

# %% [markdown]
# Что нужно понять:
# - Откуда брать данные
# - Какие инструменты использовать
# - Какие метрики хочет видеть заказчик
# - Какой ответ на вопрос и/или на уточненный вопрос

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import files


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

plt.style.use('ggplot')
# sns.set_theme(style='darkgrid')

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# # Подгрузим данные

# %%
df = pd.read_csv(
    "https://covid.ourworldindata.org/data/owid-covid-data.csv",
    parse_dates=['date'],
    low_memory=False,
)
df['date'] = df['date'].dt.date

# %% [markdown]
# # Ознакомимся с датасетом

# %% [markdown]
# # Посмотрим на то, что нас интересует

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 178553      ZWE    Africa     Zimbabwe  2022-04-09     246925.0        0.0
# 178554      ZWE    Africa     Zimbabwe  2022-04-10     246958.0       33.0
# 178555      ZWE    Africa     Zimbabwe  2022-04-11     247010.0       52.0
# 178556      ZWE    Africa     Zimbabwe  2022-04-12     247094.0       84.0
# 178557      ZWE    Africa     Zimbabwe  2022-04-13     247160.0       66.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 178553              63.429        5457.0         0.0                1.571
# 178554              61.857        5457.0         0.0                1.571
# 178555              56.857        5460.0         3.0                1.286
# 178556              50.000        5460.0         0.0                1.286
# 178557              51.000        5460.0         0.0                1.000
#
#         total_cases_per_million  new_cases_per_million  \
# 0                         0.126                  0.126
# 1                         0.126                  0.000
# 2                         0.126                  0.000
# 3                         0.126                  0.000
# 4                         0.126                  0.000
# ...                         ...                    ...
# 178553                16361.132                  0.000
# 178554                16363.318                  2.187
# 178555                16366.764                  3.445
# 178556                16372.330                  5.566
# 178557                16376.703                  4.373
#
#         new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                                  NaN                       NaN
# 1                                  NaN                       NaN
# 2                                  NaN                       NaN
# 3                                  NaN                       NaN
# 4                                  NaN                       NaN
# ...                                ...                       ...
# 178553                           4.203                   361.578
# 178554                           4.099                   361.578
# 178555                           3.767                   361.777
# 178556                           3.313                   361.777
# 178557                           3.379                   361.777
#
#         new_deaths_per_million  new_deaths_smoothed_per_million  \
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                          NaN                              NaN
# ...                        ...                              ...
# 178553                   0.000                            0.104
# 178554                   0.000                            0.104
# 178555                   0.199                            0.085
# 178556                   0.000                            0.085
# 178557                   0.000                            0.066
#
#         reproduction_rate  icu_patients  icu_patients_per_million  \
# 0                     NaN           NaN                       NaN
# 1                     NaN           NaN                       NaN
# 2                     NaN           NaN                       NaN
# 3                     NaN           NaN                       NaN
# 4                     NaN           NaN                       NaN
# ...                   ...           ...                       ...
# 178553                NaN           NaN                       NaN
# 178554                NaN           NaN                       NaN
# 178555                NaN           NaN                       NaN
# 178556                NaN           NaN                       NaN
# 178557                NaN           NaN                       NaN
#
#         hosp_patients  hosp_patients_per_million  weekly_icu_admissions  \
# 0                 NaN                        NaN                    NaN
# 1                 NaN                        NaN                    NaN
# 2                 NaN                        NaN                    NaN
# 3                 NaN                        NaN                    NaN
# 4                 NaN                        NaN                    NaN
# ...               ...                        ...                    ...
# 178553            NaN                        NaN                    NaN
# 178554            NaN                        NaN                    NaN
# 178555            NaN                        NaN                    NaN
# 178556            NaN                        NaN                    NaN
# 178557            NaN                        NaN                    NaN
#
#         weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                                     NaN                     NaN
# 1                                     NaN                     NaN
# 2                                     NaN                     NaN
# 3                                     NaN                     NaN
# 4                                     NaN                     NaN
# ...                                   ...                     ...
# 178553                                NaN                     NaN
# 178554                                NaN                     NaN
# 178555                                NaN                     NaN
# 178556                                NaN                     NaN
# 178557                                NaN                     NaN
#
#         weekly_hosp_admissions_per_million  total_tests  new_tests  \
# 0                                      NaN          NaN        NaN
# 1                                      NaN          NaN        NaN
# 2                                      NaN          NaN        NaN
# 3                                      NaN          NaN        NaN
# 4                                      NaN          NaN        NaN
# ...                                    ...          ...        ...
# 178553                                 NaN          NaN        NaN
# 178554                                 NaN    2213383.0        NaN
# 178555                                 NaN          NaN        NaN
# 178556                                 NaN          NaN        NaN
# 178557                                 NaN          NaN        NaN
#
#         total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                            NaN                     NaN                 NaN
# 1                            NaN                     NaN                 NaN
# 2                            NaN                     NaN                 NaN
# 3                            NaN                     NaN                 NaN
# 4                            NaN                     NaN                 NaN
# ...                          ...                     ...                 ...
# 178553                       NaN                     NaN              3118.0
# 178554                   146.658                     NaN              2968.0
# 178555                       NaN                     NaN                 NaN
# 178556                       NaN                     NaN                 NaN
# 178557                       NaN                     NaN                 NaN
#
#         new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# 0                                   NaN            NaN             NaN
# 1                                   NaN            NaN             NaN
# 2                                   NaN            NaN             NaN
# 3                                   NaN            NaN             NaN
# 4                                   NaN            NaN             NaN
# ...                                 ...            ...             ...
# 178553                            0.207         0.0203            49.2
# 178554                            0.197         0.0208            48.0
# 178555                              NaN            NaN             NaN
# 178556                              NaN            NaN             NaN
# 178557                              NaN            NaN             NaN
#
#             tests_units  total_vaccinations  people_vaccinated  \
# 0                   NaN                 NaN                NaN
# 1                   NaN                 NaN                NaN
# 2                   NaN                 NaN                NaN
# 3                   NaN                 NaN                NaN
# 4                   NaN                 NaN                NaN
# ...                 ...                 ...                ...
# 178553  tests performed          10005905.0          5707409.0
# 178554  tests performed          10025127.0          5721969.0
# 178555              NaN          10043468.0          5734219.0
# 178556              NaN          10074016.0          5753797.0
# 178557              NaN                 NaN                NaN
#
#         people_fully_vaccinated  total_boosters  new_vaccinations  \
# 0                           NaN             NaN               NaN
# 1                           NaN             NaN               NaN
# 2                           NaN             NaN               NaN
# 3                           NaN             NaN               NaN
# 4                           NaN             NaN               NaN
# ...                         ...             ...               ...
# 178553                3597994.0        700502.0           66722.0
# 178554                3599536.0        703622.0           19222.0
# 178555                3600666.0        708583.0           18341.0
# 178556                3604044.0        716175.0           30548.0
# 178557                      NaN             NaN               NaN
#
#         new_vaccinations_smoothed  total_vaccinations_per_hundred  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
# ...                           ...                             ...
# 178553                    57912.0                           66.30
# 178554                    47237.0                           66.43
# 178555                    39038.0                           66.55
# 178556                    38070.0                           66.75
# 178557                        NaN                             NaN
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# ...                               ...                                  ...
# 178553                          37.82                                23.84
# 178554                          37.91                                23.85
# 178555                          37.99                                23.86
# 178556                          38.12                                23.88
# 178557                            NaN                                  NaN
#
#         total_boosters_per_hundred  new_vaccinations_smoothed_per_million  \
# 0                              NaN                                    NaN
# 1                              NaN                                    NaN
# 2                              NaN                                    NaN
# 3                              NaN                                    NaN
# 4                              NaN                                    NaN
# ...                            ...                                    ...
# 178553                        4.64                                 3837.0
# 178554                        4.66                                 3130.0
# 178555                        4.70                                 2587.0
# 178556                        4.75                                 2522.0
# 178557                         NaN                                    NaN
#
#         new_people_vaccinated_smoothed  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 178553                         35961.0
# 178554                         29170.0
# 178555                         24540.0
# 178556                         23541.0
# 178557                             NaN
#
#         new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# 0                                              NaN              8.33
# 1                                              NaN              8.33
# 2                                              NaN              8.33
# 3                                              NaN              8.33
# 4                                              NaN              8.33
# ...                                            ...               ...
# 178553                                       0.238             61.11
# 178554                                       0.193             61.11
# 178555                                       0.163             61.11
# 178556                                       0.156               NaN
# 178557                                         NaN               NaN
#
#         population  population_density  median_age  aged_65_older  \
# 0       39835428.0              54.422        18.6          2.581
# 1       39835428.0              54.422        18.6          2.581
# 2       39835428.0              54.422        18.6          2.581
# 3       39835428.0              54.422        18.6          2.581
# 4       39835428.0              54.422        18.6          2.581
# ...            ...                 ...         ...            ...
# 178553  15092171.0              42.729        19.6          2.822
# 178554  15092171.0              42.729        19.6          2.822
# 178555  15092171.0              42.729        19.6          2.822
# 178556  15092171.0              42.729        19.6          2.822
# 178557  15092171.0              42.729        19.6          2.822
#
#         aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0               1.337        1803.987              NaN                597.029
# 1               1.337        1803.987              NaN                597.029
# 2               1.337        1803.987              NaN                597.029
# 3               1.337        1803.987              NaN                597.029
# 4               1.337        1803.987              NaN                597.029
# ...               ...             ...              ...                    ...
# 178553          1.882        1899.775             21.4                307.846
# 178554          1.882        1899.775             21.4                307.846
# 178555          1.882        1899.775             21.4                307.846
# 178556          1.882        1899.775             21.4                307.846
# 178557          1.882        1899.775             21.4                307.846
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 0                      9.59             NaN           NaN
# 1                      9.59             NaN           NaN
# 2                      9.59             NaN           NaN
# 3                      9.59             NaN           NaN
# 4                      9.59             NaN           NaN
# ...                     ...             ...           ...
# 178553                 1.82             1.6          30.7
# 178554                 1.82             1.6          30.7
# 178555                 1.82             1.6          30.7
# 178556                 1.82             1.6          30.7
# 178557                 1.82             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                       37.746                         0.5            64.83
# 1                       37.746                         0.5            64.83
# 2                       37.746                         0.5            64.83
# 3                       37.746                         0.5            64.83
# 4                       37.746                         0.5            64.83
# ...                        ...                         ...              ...
# 178553                  36.791                         1.7            61.49
# 178554                  36.791                         1.7            61.49
# 178555                  36.791                         1.7            61.49
# 178556                  36.791                         1.7            61.49
# 178557                  36.791                         1.7            61.49
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 0                         0.511                                   NaN
# 1                         0.511                                   NaN
# 2                         0.511                                   NaN
# 3                         0.511                                   NaN
# 4                         0.511                                   NaN
# ...                         ...                                   ...
# 178553                    0.571                                   NaN
# 178554                    0.571                                   NaN
# 178555                    0.571                                   NaN
# 178556                    0.571                                   NaN
# 178557                    0.571                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 178553                          NaN               NaN
# 178554                          NaN               NaN
# 178555                          NaN               NaN
# 178556                          NaN               NaN
# 178557                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 178553                                      NaN
# 178554                                      NaN
# 178555                                      NaN
# 178556                                      NaN
# 178557                                      NaN
#
# [178558 rows x 67 columns]

# %% [markdown]
# # Выберем то, что интересует

# %%
# можно воспользоваться срезом по датам с помощью
# pd.to_datetime('2022-01-01').date()
europe = df[df['continent'] == 'Europe']

# %% [markdown]
# # Попробуем выделить наиболее значимые и простые столбцы / агрегаты
# Можно использовать популярные методы `pandas.DataFrame`:
# - `.groupby()`
# - `.isna()`
# - `.sum()`
# - `.mean()`

# %%
# посмотрите, сколько пропусков по столбцам для Европы

# %%
# посмотрите, сколько в среднем новых заболевших в Европе в апреле

# %%
# extra
# посмотрите, какой средний процент от населения составляют все случаи в апреле

# %% [markdown]
# # Построим наиболее значимые и очевидные метрики

# %%
# всего случаев

# %%
# новых случаев

# %%
# всего смертей

# %%
# новых смертей

# %% [markdown]
# # Что не так с этими графиками?
# - умная мысль 1
# - умная мысль 2
# - гениальное заключение 3

# %% [markdown]
# # А теперь давайте попробуем построить график, который уже и показывать не слишком стыдно

# %%
country = 'Russia'
country_df = df[df['location'] == country]

# %%
# plotting country_df
fig, (ax0, ax1) = plt.subplots(2, 1, figsize=(8, 14))
ax0.set_title(f'Cases and deaths of COVID-19 in {country} by date', y=1.05)
ax1.set_xlabel('Date')
red, blue = plt.cm.RdBu([0.01, 0.99])

# total cases
ax0.plot(country_df.date, country_df.total_cases, color=blue)
plt.setp(ax0.get_xticklabels(), rotation=45)

# new cases
ax2 = ax0.twinx()
ax2.plot(country_df.date, country_df.new_cases, color=red)
ax2.grid(None)

# total deaths
ax1.plot(country_df.date, country_df.total_deaths, color=blue)
plt.setp(ax1.get_xticklabels(), rotation=45)

# new deaths
ax3 = ax1.twinx()
ax3.plot(country_df.date, country_df.new_deaths, color=red)
ax3.grid(None)

# prettifying plots
for ax, ylabel, color in zip([ax0, ax1, ax2, ax3],
                             ['Total cases',
                              'Total deaths',
                              'New cases',
                              'New deaths'],
                             [blue, blue, red, red]):
    ax.set_ylabel(ylabel, color=color)
    ax.tick_params('y', colors=color)
    ax.set_ylim(0)
    ax.set_yticks(np.linspace(*ax.get_ybound(), 10))

plt.show(block=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/colors.py:263: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   c = np.array(c)

# %% [markdown]
# # А что, если построить рядом сразу несколько стран?
# Без проблем!

# %%
countries = (
    'Russia',
    'United States',
    'United Kingdom',
    'Sweden',
)

# %%
fig, (ax0, ax1) = plt.subplots(2, 1, figsize=(13, 13))
ax0.set_title(f'Cases and deaths of COVID-19 in {country} by date', y=1.05)

sns.lineplot(
    x='date',
    y='total_cases',
    data=df[df['location'].isin(countries)],
    hue='location',
    ax=ax0,
)
ax0.set_ylabel('Total cases')
ax0.set_xlabel('')

sns.lineplot(
    x='date',
    y='new_cases',
    data=df[df['location'].isin(countries)],
    hue='location',
    ax=ax1,
)
ax1.set_ylabel('Total cases')
ax1.set_xlabel('Date')

plt.show()

# %% [markdown]
# # Давайте выгрузим часть данных для заказчика

# %%
cols = [
    'location',
    'date',
    'total_cases',
    'new_cases',
    'total_deaths',
    'new_deaths',
    'total_tests',
    'new_tests',
    'total_vaccinations',
    'people_vaccinated',
    'people_fully_vaccinated',
    'population',
    'median_age',
    'aged_65_older',
]
europe[europe.date >= pd.to_datetime('2022-01-01').date()].to_excel('covid.xlsx', index=False)
# europe[europe.date >= pd.to_datetime('2022-01-01').date()].to_csv('covid.csv', index=False)

files.download('covid.xlsx')
# files.download('covid.csv')
